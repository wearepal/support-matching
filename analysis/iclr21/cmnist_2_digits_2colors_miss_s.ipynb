# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
from utils import generate_table

# %%
base_path = Path("../../experiments/cmnist/2digits/2colors/2missing/subsampled/")

subsampled_fallen_sun = {
    ("\\texttt{ZSF+bal.\\ (ranking)}", ""): "cmnist_ranking.csv",
#     ("\\texttt{ZSF+bal.\\ (ranking) - no predictor}", ""): "cmnist_ranking_no_predictors.csv",
    ("\\texttt{ZSF+bal.\\ (k-means)}", ""): "cmnist_kmeans.csv",
    ("\\texttt{ZSF+bal.\\ (ground truth)}", ""): "cmnist_perfect_cluster.csv",
    ("\\texttt{ZSF}", ""): "cmnist_no_cluster.csv",
    ("\\texttt{FWD \\cite{HasSriNamLia18}}", "eta"): "cmnist_dro_baseline_color_60epochs.csv",
    ("\\texttt{CNN}", ""): "cmnist_cnn_baseline_color_60epochs.csv",
}

# %%
def gather(file_dict):
    df_all = pd.DataFrame()
    for (approach, param), filename in file_dict.items():
        df = pd.read_csv(base_path / filename)
        df.insert(0, "approach", approach)
        if param:
            df["approach"] = df["approach"] + " (" + df[param].astype(str) + ")"
        df_all = pd.concat([df_all, df], axis="index", ignore_index=True, sort=False)
    return df_all
df = gather(subsampled_fallen_sun)

# %%
df
# Out:
#                           approach  seed      data              method  \
# 0   \texttt{ZSF + bal.\ (ranking)}     1  x_zero_s  pytorch_classifier
# 1   \texttt{ZSF + bal.\ (ranking)}     2  x_zero_s  pytorch_classifier
# 2   \texttt{ZSF + bal.\ (ranking)}     4  x_zero_s  pytorch_classifier
# 3   \texttt{ZSF + bal.\ (ranking)}     8  x_zero_s  pytorch_classifier
# 4   \texttt{ZSF + bal.\ (ranking)}     5  x_zero_s  pytorch_classifier
# ..                             ...   ...       ...                 ...
# 75                    \texttt{CNN}     5  baseline                 cnn
# 76                    \texttt{CNN}     6  baseline                 cnn
# 77                    \texttt{CNN}     8  baseline                 cnn
# 78                    \texttt{CNN}     7  baseline                 cnn
# 79                    \texttt{CNN}     3  baseline                 cnn
#
#                                             wandb_url  cluster_test_acc  \
# 0   https://wandb.ai/predictive-analytics-lab/fdm/...          0.529791
# 1   https://wandb.ai/predictive-analytics-lab/fdm/...          0.370407
# 2   https://wandb.ai/predictive-analytics-lab/fdm/...          0.328203
# 3   https://wandb.ai/predictive-analytics-lab/fdm/...          0.875869
# 4   https://wandb.ai/predictive-analytics-lab/fdm/...          0.785998
# ..                                                ...               ...
# 75                                             (None)               NaN
# 76                                             (None)               NaN
# 77                                             (None)               NaN
# 78                                             (None)               NaN
# 79                                             (None)               NaN
#
#     cluster_context_acc  Accuracy       TPR       TNR  ...  \
# 0              0.627833  0.874876  0.914460  0.837209  ...
# 1              0.416051  0.657895  0.523422  0.785853  ...
# 2              0.398530  0.659881  0.781059  0.544574  ...
# 3              0.893005  0.992552  1.000000  0.985465  ...
# 4              0.821631  0.776564  0.874745  0.683140  ...
# ..                  ...       ...       ...       ...  ...
# 75                  NaN  0.781033  0.860489  0.705426  ...
# 76                  NaN  0.800894  0.872709  0.732558  ...
# 77                  NaN  0.718471  0.703666  0.732558  ...
# 78                  NaN  0.735353  0.764766  0.707364  ...
# 79                  NaN  0.776564  0.601833  0.942829  ...
#
#     prob_pos_colour_0.0/colour_1.0  TPR_colour_1.0  TPR_colour_0.0  \
# 0                         0.853759        0.996094        0.825532
# 1                         0.442253        0.000000        0.998058
# 2                         0.641683        1.000000        0.574257
# 3                         0.978095        1.000000        1.000000
# 4                         0.746983        0.742616        0.998031
# ..                             ...             ...             ...
# 75                        0.787454        1.000000        0.710970
# 76                        0.838588        0.998077        0.731602
# 77                        0.969770        0.409736        1.000000
# 78                        0.895371        0.523711        1.000000
# 79                        0.299335        0.998039        0.173729
#
#     TPR_colour_0.0-colour_1.0  TPR_colour_0.0/colour_1.0  TNR_colour_1.0  \
# 0                    0.170562                   0.828769        0.998124
# 1                    0.998058                   0.000000        0.577519
# 2                    0.425743                   0.574257        0.994275
# 3                    0.000000                   1.000000        0.996109
# 4                    0.255415                   0.744081        0.386364
# ..                        ...                        ...             ...
# 75                   0.289030                   0.710970        0.998016
# 76                   0.266475                   0.733011        1.000000
# 77                   0.590264                   0.409736        0.467181
# 78                   0.476289                   0.523711        0.421965
# 79                   0.824310                   0.174070        1.000000
#
#     TNR_colour_0.0  TNR_colour_0.0-colour_1.0  TNR_colour_0.0/colour_1.0  eta
# 0         0.665331                   0.332793                   0.666581  NaN
# 1         0.994186                   0.416667                   0.580897  NaN
# 2         0.080709                   0.913566                   0.081173  NaN
# 3         0.974903                   0.021205                   0.978712  NaN
# 4         0.994048                   0.607684                   0.388677  NaN
# ..             ...                        ...                        ...  ...
# 75        0.426136                   0.571880                   0.426984  NaN
# 76        0.489834                   0.510166                   0.489834  NaN
# 77        1.000000                   0.532819                   0.467181  NaN
# 78        0.996101                   0.574136                   0.423617  NaN
# 79        0.881048                   0.118952                   0.881048  NaN
#
# [80 rows x 28 columns]

# %%
metrics_renames={
    "cluster_context_acc": "Cluster. Acc. $\\uparrow$",
    "Accuracy": "Acc. $\\uparrow$",
    "prob_pos_colour_0.0/colour_1.0": "AR ratio $\\rightarrow 1.0 \\leftarrow$",
    "TPR_colour_0.0/colour_1.0": "TPR ratio $\\rightarrow 1.0 \\leftarrow$",
    "TNR_colour_0.0/colour_1.0": "TNR ratio $\\rightarrow 1.0 \\leftarrow$",
}
tab = generate_table(
    df=df,
    type_renames={"x_zero_s": "ours"},
    metrics=list(metrics_renames.values()),
#     query="~(type == 'baseline' & (approach.str.contains('E&S') | approach.str.contains('kmeans') | approach.str.contains('ranking') | approach == 'true_balancing')) & ~(type == 'ours' & classifier == 'LRCV')",
    query="~(approach.str.contains('0.01') | approach.str.contains('0.5') | approach.str.contains('1.0'))",
    with_classifier=False,
    metrics_renames=metrics_renames,
)
tab
# Out:
#                                                   Cluster. Acc. $\uparrow$  \
# type     approach
# ours     \texttt{ZSF + bal.\ (ranking)}                     0.69 $\pm$ 0.2
#          \texttt{ZSF + bal.\ (k-means)}                    0.71 $\pm$ 0.15
#          \texttt{ZSF + bal.\ (groundtruth)}                  0.0 $\pm$ 0.0
#          \texttt{ZSF}                                        0.0 $\pm$ 0.0
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.1)                      N/A
#          \texttt{CNN}                                                  N/A
#
#                                                    Acc. $\uparrow$  \
# type     approach
# ours     \texttt{ZSF + bal.\ (ranking)}            0.83 $\pm$ 0.12
#          \texttt{ZSF + bal.\ (k-means)}            0.79 $\pm$ 0.11
#          \texttt{ZSF + bal.\ (groundtruth)}        0.84 $\pm$ 0.12
#          \texttt{ZSF}                              0.88 $\pm$ 0.14
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.1)  0.76 $\pm$ 0.02
#          \texttt{CNN}                              0.76 $\pm$ 0.02
#
#                                                   AR ratio $\rightarrow 1.0 \leftarrow$  \
# type     approach
# ours     \texttt{ZSF + bal.\ (ranking)}                                 0.75 $\pm$ 0.17
#          \texttt{ZSF + bal.\ (k-means)}                                  0.64 $\pm$ 0.2
#          \texttt{ZSF + bal.\ (groundtruth)}                             0.92 $\pm$ 0.03
#          \texttt{ZSF}                                                    0.84 $\pm$ 0.1
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.1)                       0.26 $\pm$ 0.22
#          \texttt{CNN}                                                   0.47 $\pm$ 0.41
#
#                                                   TPR ratio $\rightarrow 1.0 \leftarrow$  \
# type     approach
# ours     \texttt{ZSF + bal.\ (ranking)}                                  0.76 $\pm$ 0.32
#          \texttt{ZSF + bal.\ (k-means)}                                  0.59 $\pm$ 0.31
#          \texttt{ZSF + bal.\ (groundtruth)}                               0.7 $\pm$ 0.24
#          \texttt{ZSF}                                                    0.69 $\pm$ 0.28
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.1)                        0.42 $\pm$ 0.45
#          \texttt{CNN}                                                     0.32 $\pm$ 0.3
#
#                                                   TNR ratio $\rightarrow 1.0 \leftarrow$
# type     approach
# ours     \texttt{ZSF + bal.\ (ranking)}                                  0.58 $\pm$ 0.29
#          \texttt{ZSF + bal.\ (k-means)}                                  0.58 $\pm$ 0.35
#          \texttt{ZSF + bal.\ (groundtruth)}                              0.65 $\pm$ 0.25
#          \texttt{ZSF}                                                     0.8 $\pm$ 0.32
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.1)                         0.6 $\pm$ 0.46
#          \texttt{CNN}                                                    0.71 $\pm$ 0.26

# %%
print(tab.reset_index(level=0, drop=True, inplace=False).to_latex(escape=False, column_format="lccccc"))
# Out:
# \begin{tabular}{lccccc}
# \toprule
# {} & Cluster. Acc. $\uparrow$ &  Acc. $\uparrow$ & AR ratio $\rightarrow 1.0 \leftarrow$ & TPR ratio $\rightarrow 1.0 \leftarrow$ & TNR ratio $\rightarrow 1.0 \leftarrow$ \\
# approach                                 &                          &                  &                                       &                                        &                                        \\
# \midrule
# \texttt{ZSF + bal.\ (ranking)}           &           0.69 $\pm$ 0.2 &  0.83 $\pm$ 0.12 &                       0.75 $\pm$ 0.17 &                        0.76 $\pm$ 0.32 &                        0.58 $\pm$ 0.29 \\
# \texttt{ZSF + bal.\ (k-means)}           &          0.71 $\pm$ 0.15 &  0.79 $\pm$ 0.11 &                        0.64 $\pm$ 0.2 &                        0.59 $\pm$ 0.31 &                        0.58 $\pm$ 0.35 \\
# \texttt{ZSF + bal.\ (groundtruth)}       &            0.0 $\pm$ 0.0 &  0.84 $\pm$ 0.12 &                       0.92 $\pm$ 0.03 &                         0.7 $\pm$ 0.24 &                        0.65 $\pm$ 0.25 \\
# \texttt{ZSF}                             &            0.0 $\pm$ 0.0 &  0.88 $\pm$ 0.14 &                        0.84 $\pm$ 0.1 &                        0.69 $\pm$ 0.28 &                         0.8 $\pm$ 0.32 \\
# \texttt{FWD \cite{HasSriNamLia18}} (0.1) &                      N/A &  0.76 $\pm$ 0.02 &                       0.26 $\pm$ 0.22 &                        0.42 $\pm$ 0.45 &                         0.6 $\pm$ 0.46 \\
# \texttt{CNN}                             &                      N/A &  0.76 $\pm$ 0.02 &                       0.47 $\pm$ 0.41 &                         0.32 $\pm$ 0.3 &                        0.71 $\pm$ 0.26 \\
# \bottomrule
# \end{tabular}
