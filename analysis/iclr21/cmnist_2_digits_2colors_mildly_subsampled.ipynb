# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
from utils import generate_table

# %%
base_path = Path("../../experiments/cmnist/2digits/2colors/1missing/mildly_subsampled/")

subsampled_fallen_sun = {
    ("\\texttt{ZSF+bal.\\ (ranking)}", ""): "cmnist_ranking.csv",
#     ("\\texttt{ZSF+bal.\\ (ranking) - no predictor}", ""): "cmnist_ranking_no_predictors.csv",
    ("\\texttt{ZSF+bal.\\ (k-means)}", ""): "cmnist_kmeans.csv",
    ("\\texttt{ZSF+bal.\\ (ground truth)}", ""): "cmnist_perfect_cluster.csv",
    ("\\texttt{ZSF}", ""): "cmnist_no_cluster.csv",
    ("\\texttt{FWD \\cite{HasSriNamLia18}}", "eta"): "cmnist_dro_baseline_color_60epochs.csv",
    ("\\texttt{CNN}", ""): "cmnist_cnn_baseline_color_60epochs.csv",
}

# %%
def gather(file_dict):
    df_all = pd.DataFrame()
    for (approach, param), filename in file_dict.items():
        df = pd.read_csv(base_path / filename)
        df.insert(0, "approach", approach)
        if param:
            df["approach"] = df["approach"] + " (" + df[param].astype(str) + ")"
        df_all = pd.concat([df_all, df], axis="index", ignore_index=True, sort=False)
    return df_all
df = gather(subsampled_fallen_sun)

# %%
df
# Out:
#                         approach  seed      data              method  \
# 0   \texttt{ZSF+bal.\ (ranking)}     1  x_zero_s  pytorch_classifier
# 1   \texttt{ZSF+bal.\ (ranking)}     2  x_zero_s  pytorch_classifier
# 2   \texttt{ZSF+bal.\ (ranking)}     4  x_zero_s  pytorch_classifier
# 3   \texttt{ZSF+bal.\ (ranking)}     5  x_zero_s  pytorch_classifier
# 4   \texttt{ZSF+bal.\ (ranking)}     6  x_zero_s  pytorch_classifier
# ..                           ...   ...       ...                 ...
# 67                  \texttt{CNN}     6  baseline                 cnn
# 68                  \texttt{CNN}     8  baseline                 cnn
# 69                  \texttt{CNN}     5  baseline                 cnn
# 70                  \texttt{CNN}     3  baseline                 cnn
# 71                  \texttt{CNN}     7  baseline                 cnn
#
#                                             wandb_url  cluster_test_acc  \
# 0   https://wandb.ai/predictive-analytics-lab/fdm/...          0.769116
# 1   https://wandb.ai/predictive-analytics-lab/fdm/...          0.896226
# 2   https://wandb.ai/predictive-analytics-lab/fdm/...          0.451341
# 3   https://wandb.ai/predictive-analytics-lab/fdm/...          0.962264
# 4   https://wandb.ai/predictive-analytics-lab/fdm/...          0.756207
# ..                                                ...               ...
# 67                                             (None)               NaN
# 68                                             (None)               NaN
# 69                                             (None)               NaN
# 70                                             (None)               NaN
# 71                                             (None)               NaN
#
#     cluster_context_acc  Accuracy       TPR       TNR  ...  \
# 0              0.850908  0.813307  0.617108  1.000000  ...
# 1              0.928071  0.973684  0.951120  0.995155  ...
# 2              0.514415  0.971202  0.942974  0.998062  ...
# 3              0.972254  0.813803  0.631365  0.987403  ...
# 4              0.832549  0.836643  0.667006  0.998062  ...
# ..                  ...       ...       ...       ...  ...
# 67                  NaN  0.770606  0.531568  0.998062  ...
# 68                  NaN  0.752234  0.498982  0.993217  ...
# 69                  NaN  0.762661  0.517312  0.996124  ...
# 70                  NaN  0.765144  0.519348  0.999031  ...
# 71                  NaN  0.756207  0.506110  0.994186  ...
#
#     prob_pos_colour_0.0/colour_1.0  TPR_colour_1.0  TPR_colour_0.0  \
# 0                         0.200491        0.998047        0.202128
# 1                         0.848764        0.899358        0.998058
# 2                         0.934292        0.995807        0.893069
# 3                         0.217117        0.236287        1.000000
# 4                         0.263119        0.294372        0.998077
# ..                             ...             ...             ...
# 67                        0.003862        0.004329        1.000000
# 68                        0.002000        1.000000        0.002028
# 69                        0.000000        0.000000        1.000000
# 70                        0.000000        0.000000        1.000000
# 71                        0.000000        1.000000        0.000000
#
#     TPR_colour_0.0-colour_1.0  TPR_colour_0.0/colour_1.0  TNR_colour_1.0  \
# 0                    0.795919                   0.202523        1.000000
# 1                    0.098701                   0.901107        1.000000
# 2                    0.102738                   0.896830        0.996183
# 3                    0.763713                   0.236287        1.000000
# 4                    0.703705                   0.294939        1.000000
# ..                        ...                        ...             ...
# 67                   0.995671                   0.004329        1.000000
# 68                   0.997972                   0.002028        0.986381
# 69                   1.000000                   0.000000        1.000000
# 70                   1.000000                   0.000000        1.000000
# 71                   1.000000                   0.000000        0.988304
#
#     TNR_colour_0.0  TNR_colour_0.0-colour_1.0  TNR_colour_0.0/colour_1.0  eta
# 0         1.000000                   0.000000                   1.000000  NaN
# 1         0.990310                   0.009690                   0.990310  NaN
# 2         1.000000                   0.003817                   0.996183  NaN
# 3         0.974206                   0.025794                   0.974206  NaN
# 4         0.995927                   0.004073                   0.995927  NaN
# ..             ...                        ...                        ...  ...
# 67        0.995927                   0.004073                   0.995927  NaN
# 68        1.000000                   0.013619                   0.986381  NaN
# 69        0.992063                   0.007937                   0.992063  NaN
# 70        0.998134                   0.001866                   0.998134  NaN
# 71        1.000000                   0.011696                   0.988304  NaN
#
# [72 rows x 28 columns]

# %%
metrics_renames={
    "cluster_context_acc": "Cluster. Acc. $\\uparrow$",
    "Accuracy": "Acc. $\\uparrow$",
    "prob_pos_colour_0.0/colour_1.0": "AR ratio $\\rightarrow 1.0 \\leftarrow$",
    "TPR_colour_0.0/colour_1.0": "TPR ratio $\\rightarrow 1.0 \\leftarrow$",
    "TNR_colour_0.0/colour_1.0": "TNR ratio $\\rightarrow 1.0 \\leftarrow$",
}
tab = generate_table(
    df=df,
    type_renames={"x_zero_s": "ours"},
    metrics=list(metrics_renames.values()),
#     query="~(type == 'baseline' & (approach.str.contains('E&S') | approach.str.contains('kmeans') | approach.str.contains('ranking') | approach == 'true_balancing')) & ~(type == 'ours' & classifier == 'LRCV')",
    query="~(type == 'asfasdf')",#"~(approach.str.contains('0.01') | approach.str.contains('0.1') | approach.str.contains('1.0'))",
    with_classifier=False,
    metrics_renames=metrics_renames,
)
tab
# Out:
#                                                    Cluster. Acc. $\uparrow$  \
# type     approach
# ours     \texttt{ZSF+bal.\ (ranking)}                       0.88 $\pm$ 0.15
#          \texttt{ZSF+bal.\ (k-means)}                       0.78 $\pm$ 0.15
#          \texttt{ZSF+bal.\ (ground truth)}                    0.0 $\pm$ 0.0
#          \texttt{ZSF}                                         0.0 $\pm$ 0.0
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.01)                      N/A
#          \texttt{FWD \cite{HasSriNamLia18}} (0.1)                       N/A
#          \texttt{FWD \cite{HasSriNamLia18}} (0.5)                       N/A
#          \texttt{FWD \cite{HasSriNamLia18}} (1.0)                       N/A
#          \texttt{CNN}                                                   N/A
#
#                                                       Acc. $\uparrow$  \
# type     approach
# ours     \texttt{ZSF+bal.\ (ranking)}                  0.9 $\pm$ 0.07
#          \texttt{ZSF+bal.\ (k-means)}                 0.96 $\pm$ 0.02
#          \texttt{ZSF+bal.\ (ground truth)}            0.93 $\pm$ 0.04
#          \texttt{ZSF}                                 0.81 $\pm$ 0.05
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.01)  0.764 $\pm$ 0.009
#          \texttt{FWD \cite{HasSriNamLia18}} (0.1)     0.77 $\pm$ 0.02
#          \texttt{FWD \cite{HasSriNamLia18}} (0.5)     0.79 $\pm$ 0.05
#          \texttt{FWD \cite{HasSriNamLia18}} (1.0)      0.58 $\pm$ 0.1
#          \texttt{CNN}                                0.76 $\pm$ 0.007
#
#                                                    AR ratio $\rightarrow 1.0 \leftarrow$  \
# type     approach
# ours     \texttt{ZSF+bal.\ (ranking)}                                    0.56 $\pm$ 0.32
#          \texttt{ZSF+bal.\ (k-means)}                                    0.81 $\pm$ 0.12
#          \texttt{ZSF+bal.\ (ground truth)}                               0.72 $\pm$ 0.17
#          \texttt{ZSF}                                                    0.22 $\pm$ 0.23
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.01)                       0.02 $\pm$ 0.04
#          \texttt{FWD \cite{HasSriNamLia18}} (0.1)                        0.04 $\pm$ 0.11
#          \texttt{FWD \cite{HasSriNamLia18}} (0.5)                        0.14 $\pm$ 0.19
#          \texttt{FWD \cite{HasSriNamLia18}} (1.0)                      0.001 $\pm$ 0.001
#          \texttt{CNN}                                                  0.001 $\pm$ 0.001
#
#                                                    TPR ratio $\rightarrow 1.0 \leftarrow$  \
# type     approach
# ours     \texttt{ZSF+bal.\ (ranking)}                                     0.57 $\pm$ 0.32
#          \texttt{ZSF+bal.\ (k-means)}                                      0.83 $\pm$ 0.1
#          \texttt{ZSF+bal.\ (ground truth)}                                0.74 $\pm$ 0.16
#          \texttt{ZSF}                                                     0.22 $\pm$ 0.22
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.01)                        0.02 $\pm$ 0.04
#          \texttt{FWD \cite{HasSriNamLia18}} (0.1)                         0.05 $\pm$ 0.11
#          \texttt{FWD \cite{HasSriNamLia18}} (0.5)                          0.14 $\pm$ 0.2
#          \texttt{FWD \cite{HasSriNamLia18}} (1.0)                       0.001 $\pm$ 0.002
#          \texttt{CNN}                                                   0.001 $\pm$ 0.001
#
#                                                    TNR ratio $\rightarrow 1.0 \leftarrow$
# type     approach
# ours     \texttt{ZSF+bal.\ (ranking)}                                   0.994 $\pm$ 0.008
#          \texttt{ZSF+bal.\ (k-means)}                                   0.997 $\pm$ 0.003
#          \texttt{ZSF+bal.\ (ground truth)}                              0.998 $\pm$ 0.002
#          \texttt{ZSF}                                                   0.996 $\pm$ 0.004
# baseline \texttt{FWD \cite{HasSriNamLia18}} (0.01)                      0.992 $\pm$ 0.004
#          \texttt{FWD \cite{HasSriNamLia18}} (0.1)                       0.992 $\pm$ 0.004
#          \texttt{FWD \cite{HasSriNamLia18}} (0.5)                        0.99 $\pm$ 0.004
#          \texttt{FWD \cite{HasSriNamLia18}} (1.0)                         0.65 $\pm$ 0.44
#          \texttt{CNN}                                                   0.992 $\pm$ 0.004

# %%
print(tab.reset_index(level=0, drop=True, inplace=False).to_latex(escape=False, column_format="lccccc"))
# Out:
# \begin{tabular}{lccccc}
# \toprule
# {} & Cluster. Acc. $\uparrow$ &    Acc. $\uparrow$ & AR ratio $\rightarrow 1.0 \leftarrow$ & TPR ratio $\rightarrow 1.0 \leftarrow$ & TNR ratio $\rightarrow 1.0 \leftarrow$ \\
# approach                                 &                          &                    &                                       &                                        &                                        \\
# \midrule
# \texttt{SSL (ranking)}                   &          0.93 $\pm$ 0.05 &    0.81 $\pm$ 0.04 &                       0.26 $\pm$ 0.18 &                        0.25 $\pm$ 0.17 &                      0.992 $\pm$ 0.003 \\
# \texttt{SSL (ranking) - no predictor}    &          0.93 $\pm$ 0.05 &    0.55 $\pm$ 0.08 &                       0.17 $\pm$ 0.32 &                        0.24 $\pm$ 0.34 &                        0.96 $\pm$ 0.09 \\
# \texttt{SSL (k-means)}                   &           0.7 $\pm$ 0.12 &    0.86 $\pm$ 0.09 &                       0.47 $\pm$ 0.36 &                        0.46 $\pm$ 0.36 &                      0.994 $\pm$ 0.004 \\
# \texttt{SSL (perfect cluster)}           &            0.0 $\pm$ 0.0 &    0.89 $\pm$ 0.05 &                       0.56 $\pm$ 0.23 &                        0.55 $\pm$ 0.22 &                      0.994 $\pm$ 0.003 \\
# \texttt{SSL (no cluster)}                &            0.0 $\pm$ 0.0 &    0.78 $\pm$ 0.04 &                       0.11 $\pm$ 0.19 &                         0.1 $\pm$ 0.17 &                      0.992 $\pm$ 0.006 \\
# \texttt{FWD \cite{HasSriNamLia18}} (0.5) &                      N/A &    0.77 $\pm$ 0.04 &                       0.08 $\pm$ 0.18 &                        0.08 $\pm$ 0.17 &                      0.987 $\pm$ 0.006 \\
# \texttt{CNN}                             &                      N/A &  0.753 $\pm$ 0.006 &                       0.01 $\pm$ 0.02 &                        0.01 $\pm$ 0.02 &                      0.986 $\pm$ 0.004 \\
# \bottomrule
# \end{tabular}
