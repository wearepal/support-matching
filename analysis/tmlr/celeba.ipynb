# %%
import sys
sys.path.append("..")

# %%
from math import nan
from pathlib import Path
from wandb_utils import Metrics, plot, download_groups, MethodName, Group
from wandb_downloader import RunsDownloader

# %%
wandb = RunsDownloader(project="support-matching")

# %%
data = download_groups(wandb, {
    "celeba_no_unsmiling_females_northern_resonance_kyiv_5": Group(MethodName.ours_bag_oracle, "test/y_from_zy/"),
    "no_unsmiling_females_erm_best": Group(MethodName.erm, "test/"),
})
# Out:
# 'celeba_no_unsmiling_females_northern_resonance_kyiv_5': found 4 runs.
# 'no_unsmiling_females_erm_best': found 4 runs.

# %%
plot_kwargs = dict(
    file_format="pdf",
    fig_dim=(5, 1.0),
    file_prefix="celeba_no_unsmiling_females",
)

# %%
plot(
    data, metrics=[Metrics.rob_acc],
    # x_limits=(0.48, 1),
    **plot_kwargs,
)
